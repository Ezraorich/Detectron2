# %%
% tensorflow_version 1.x
# !pip install --upgrade h5py==2.10.0
# !git clone https://github.com/pysource7/Mask_RCNN
import sys
sys.path.append('/content/Mask_RCNN/demo')
from train_mask_rcnn_demo import *
# %matplotlib inline
# Out:
# TensorFlow 1.x selected.
# ...
#      |████████████████████████████████| 2.9 MB 5.4 MB/s
# ...
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# ...
# Cloning into 'Mask_RCNN'...
# remote: Enumerating objects: 1053, done.
# remote: Total 1053 (delta 0), reused 0 (delta 0), pack-reused 1053
# Receiving objects: 100% (1053/1053), 125.29 MiB | 30.31 MiB/s, done.
# Resolving deltas: 100% (621/621), done.
# VERS 0.2
# Using TensorFlow backend.
# ...
# ... done downloading pretrained model!

# %%
# !nvidia-smi
# Out:
# Sat Nov 27 10:41:58 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   69C    P8    34W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
images_path = 'mask_positive.zip'
annotations_path = 'annotations.json'
extract_images(os.path.join('/content/', images_path), '/content/mask_positive')
# Out:
# Extracted: 51 images

# %%
#dataset_train.count_classes()

# %%
dataset_train = load_image_dataset(os.path.join('/content/', annotations_path), '/content/mask_positive', 'train')
dataset_val = load_image_dataset(os.path.join('/content/', annotations_path), '/content/mask_positive', 'val')
print('Validation: %d'% len(dataset_val.image_ids))
# Out:
# Annotation json path:  /content/annotations.json
# Annotation json path:  /content/annotations.json
# Validation: 5

# %%
type(dataset_train)
# Out:
# train_mask_rcnn_demo.CustomDataset

# %%
for annotation in annotations:
  
  class_id = annotation['category_id']
  class_ids.add(class_id)

# %%
display_image_samples(dataset_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-d2d5c6187cf9> in <module>()
# ----> 1 display_image_samples(dataset_train)
#
# /content/Mask_RCNN/demo/train_mask_rcnn_demo.py in display_image_samples(dataset_train)
#     251     for image_id in image_ids:
#     252         image = dataset_train.load_image(image_id)
# --> 253         mask, class_ids = dataset_train.load_mask(image_id)
#     254         visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names)
#     255
#
# /content/Mask_RCNN/demo/train_mask_rcnn_demo.py in load_mask(self, image_id)
#     194
#     195         for annotation in annotations:
# --> 196             class_id = annotation['category_id']
#     197             mask = Image.new('1', (image_info['width'], image_info['height']))
#     198             mask_draw = ImageDraw.ImageDraw(mask, '1')
#
# ...

# %%
import numpy
json1_file = open('annotations.json')
json1_str = json1_file.read()
#json1_data = json.loads(json1_str)[0]
type(json1_file)
# Out:
# _io.TextIOWrapper

# %%
with open("annotations.json") as BOB:
    data=json.load(BOB)
for i in data:
  print (i)
# Out:
# info
# images
# annotations
# categories

# %%
data['category_id'] = [{'id': 1}]

# %%
for i in data:
  print (i)
# Out:
# info
# images
# annotations
# categories
# category_id

# %%
import json

with open("annotations.json") as BOB:
    data=json.load(BOB)
for x in data['images']:
  
  #print(x)

  x.update({'category_id': [1]})
  data.update(x)
  #print(x)

# %%
data
# Out:
# {'annotations': [{'area': 171559.80395320393,
#    'bbox': [665.8231827111983,
#     581.9410609037328,
#     533.8467583497054,
#     851.2691552062869],
#    'id': 0,
#    'image_id': 1,
#    'iscrowd': 0,
#    'segmentation': [[1199.6699410609037,
#      581.9410609037328,
#      1190.0510805500983,
#      851.2691552062868,
#      1137.147347740668,
#      985.9332023575638,
#      1079.434184675835,
#      1245.6424361493123,
#      1108.2907662082514,
#      1433.2102161100197,
#      968.8172888015716,
#      1433.2102161100197,
#      747.5834970530451,
#      1389.925343811395,
#      665.8231827111983,
#      1293.7367387033398,
#      930.3418467583497,
#      1168.6915520628684,
#      930.3418467583497,
#      1048.4557956777996,
#      930.3418467583497,
#      1048.4557956777996,
#      1007.2927308447937,
#      957.0766208251473,
#      983.2455795677799,
#      803.1748526522593]]},
#   {'area': 119476.67420613629,
#    'bbox': [946.6836935166993,
# ...

# %%
data_training = json.dumps(data)

# %%
import json

#aDict = {"a":54, "b":87}
#jsonString = json.dumps(aDict)
jsonFile = open("data_h.json", "w")
jsonFile.write(data_training)
jsonFile.close()

# %%
annotations_path = 'data_h.json'
dataset_train = load_image_dataset(os.path.join('/content/', annotations_path), '/content/mask_positive', 'train')
dataset_val = load_image_dataset(os.path.join('/content/', annotations_path), '/content/mask_positive', 'val')
print('Validation: %d'% len(dataset_val.image_ids))

class_number = dataset_train.count_classes()
print('Classes: {}'.format(class_number))
# Out:
# Annotation json path:  /content/data_h.json
# Annotation json path:  /content/data_h.json
# Validation: 5
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-118-43ae25fb70ab> in <module>()
#       4 print('Validation: %d'% len(dataset_val.image_ids))
#       5
# ----> 6 class_number = dataset_train.count_classes()
#       7 print('Classes: {}'.format(class_number))
#
# /content/Mask_RCNN/demo/train_mask_rcnn_demo.py in count_classes(self)
#     215
#     216             for annotation in annotations:
# --> 217                 class_id = annotation['category_id']
#     218                 class_ids.add(class_id)
#     219
#
# KeyError: 'category_id'

# %%
import json

with open("data_cat.json") as BOB:
    data=json.load(BOB)

# %%
data
# Out:
# {'annotations': [{'area': 171559.80395320393,
#    'bbox': [665.8231827111983,
#     581.9410609037328,
#     533.8467583497054,
#     851.2691552062869],
#    'id': 0,
#    'image_id': 1,
#    'iscrowd': 0,
#    'segmentation': [[1199.6699410609037,
#      581.9410609037328,
#      1190.0510805500983,
#      851.2691552062868,
#      1137.147347740668,
#      985.9332023575638,
#      1079.434184675835,
#      1245.6424361493123,
#      1108.2907662082514,
#      1433.2102161100197,
#      968.8172888015716,
#      1433.2102161100197,
#      747.5834970530451,
#      1389.925343811395,
#      665.8231827111983,
#      1293.7367387033398,
#      930.3418467583497,
#      1168.6915520628684,
#      930.3418467583497,
#      1048.4557956777996,
#      930.3418467583497,
#      1048.4557956777996,
#      1007.2927308447937,
#      957.0766208251473,
#      983.2455795677799,
#      803.1748526522593]]},
#   {'area': 119476.67420613629,
#    'bbox': [946.6836935166993,
# ...

# %%
train_features, train_labels = next(iter(train_dataloader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
